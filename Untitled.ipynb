# %%
import pandas as pd

import pylab as plt

import seaborn as sns

import numpy as np

import mysql.connector as conn

import statsmodels.api as sm

import warnings
warnings.simplefilter('ignore')

# %%
data = pd.read_excel('data/measurements2.xlsx')

# %%
measure = data.copy()

# %%
measure.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside specials gas_type  AC  \
# 0      28.0      5.0     26         21.5            12      NaN      E10   0
# 1      12.0      4.2     30         21.5            13      NaN      E10   0
# 2      11.2      5.5     38         21.5            15      NaN      E10   0
# 3      12.9      3.9     36         21.5            14      NaN      E10   0
# 4      18.5      4.5     46         21.5            15      NaN      E10   0
#
#    rain  sun  refill liters refill gas
# 0     0    0           45.0        E10
# 1     0    0            NaN        NaN
# 2     0    0            NaN        NaN
# 3     0    0            NaN        NaN
# 4     0    0            NaN        NaN

# %%
measure = measure.drop(['distance', 'refill gas', 'refill liters', 'specials'], axis = 1)

measure.temp_inside.ffill(inplace=True)

measure['speed2'] = np.power(measure.speed, 2)

# Create dummies for `gas_type`
measure = pd.get_dummies(measure, columns = ['gas_type'])

measure.head()
# Out:
#    consume  speed  temp_inside  temp_outside  AC  rain  sun  speed2  \
# 0      5.0     26         21.5            12   0     0    0     676
# 1      4.2     30         21.5            13   0     0    0     900
# 2      5.5     38         21.5            15   0     0    0    1444
# 3      3.9     36         21.5            14   0     0    0    1296
# 4      4.5     46         21.5            15   0     0    0    2116
#
#    gas_type_E10  gas_type_SP98
# 0             1              0
# 1             1              0
# 2             1              0
# 3             1              0
# 4             1              0

# %%
# LOAD DATABASE
fffff
crea_db=conn.connect(host='localhost', user='root', passwd='10081973')

cursor=crea_db.cursor()

cursor.execute('drop database if exists technical_test;')
cursor.execute('create database technical_test;')
cursor.execute('use technical_test;')

cursor.execute('drop table if exists data;')

tabla='''
        create table data (
                            consume float, speed int, temp_inside float, temp_outside int, AC int, rain int,
                            sun int, gas_type_E10 int, gas_type_SP98 int);
'''

cursor.execute(tabla)

for i in range(len(measure)):
    
    insert_query='insert into {} ({}) values {};'\
                 .format('measure', ','.join(measure.columns), tuple(measure.iloc[i].values))
    
    insert_query=f"insert into data ({','.join(measure.columns)}) values {tuple(measure.iloc[i].values)};"
    
    cursor.execute(insert_query)
    
crea_db.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 # LOAD DATABASE
# ----> 2 fffff
#       3 crea_db=conn.connect(host='localhost', user='root', passwd='10081973')
#       5 cursor=crea_db.cursor()
#
# NameError: name 'fffff' is not defined

# %%
#%% Basic functions
def clean_df(dep_var, indep_var, raw_dataframe,
              par_log_dep_var = False, par_log_indep_var = [],
              squares = [], inters = []):
    '''Devuelve el df listo para realizar regresiones.'''
    # Quitar filas con NaN en la variable dependiente y NaN en independientes
    df = raw_dataframe[raw_dataframe[dep_var].notna()]
    all_vars = indep_var.copy()
    all_vars.insert(0, dep_var)
    # Añadir variable a independientes si solo aparece en las interacciones
    for iv_pair in inters:
        for inter_var in iv_pair:
            if inter_var not in all_vars:
                all_vars.append(inter_var)
    df = df.loc[:, all_vars]
    df.dropna(inplace = True)
    df.reset_index(drop = True, inplace = True)
    # Crear columnas con log necesarias
    # Variables independientes
    for iv in par_log_indep_var:
        log_indep_var_name = 'l' + iv
        if log_indep_var_name not in indep_var:
            indep_var[indep_var.index(iv)] = log_indep_var_name
        if log_indep_var_name not in df.columns:
            df[log_indep_var_name] = np.log(df[iv])
    # Variables dependiente
    if par_log_dep_var:
        log_dep_var_name = 'l' + dep_var
        if log_dep_var_name not in df.columns:
            df[log_dep_var_name] = np.log(df[dep_var])
    # Crear variabels cuadráticas
    for sq_var in squares:
        sq_var_name = sq_var + '2'
        df[sq_var_name] = df[sq_var]**2
        indep_var.insert(indep_var.index(sq_var) + 1, sq_var_name)
    # Crear variables de interacción
    for inter in inters:
        inter_var_name = 'X'.join(inter)
        df[inter_var_name] = df[inter[0]] * df[inter[1]]
        indep_var.append(inter_var_name)
    new_df = df
    return new_df

def clean_reg(dep_var, indep_var, raw_dataframe,
              par_log_dep_var = False, par_log_indep_var = [],
              squares = [], inters = [], intercept = True,
              wls = False, weights = None):
    df = clean_df(dep_var, indep_var, raw_dataframe,
                  par_log_dep_var, par_log_indep_var,
                  squares, inters)
    if par_log_dep_var:
        dep_var = 'l' + dep_var
    y = df.loc[:, dep_var]
    X = df.loc[:, indep_var]
    if intercept:
        ones = pd.DataFrame(data = {'Intercept': [1] * len(X)})
        X = pd.concat([ones, X], axis = 1)
    regression = sm.OLS(y, X)
    if wls:
        regression = sm.WLS(y, X, weights = weights)
    results = regression.fit()
    return results

#16:35
#%% Tunned OLS models
models = {
    'speed_simple' : ['speed',
            'gas_type_E10',
            'gas_type_SP98',
            ],
    'speed_squared' : ['speed',
            'speed2',
            'gas_type_E10',
            'gas_type_SP98',
            ],
    'temp_inside' : ['speed',
            'speed2',
            'gas_type_E10',
            'gas_type_SP98',
            'temp_inside'],
    'rain' : ['speed',
            'speed2',
            'gas_type_E10',
            'gas_type_SP98',
            'temp_inside',
            'rain']}
models_dic = {} # Model name, p-value of hypothesis that consume is equal for each carburant
# Compute all models, obtain results and save them in a dictionary
for name, indep_vars in models.items():
    dep_var = 'consume'
    indep_var = indep_vars
    reg = clean_reg(dep_var, indep_var, measure,
                    intercept = True)
    print(reg.t_test('gas_type_E10 = gas_type_SP98').pvalue)
    print(reg.summary())
    models_dic[name] = {
                        'E10' : round(reg.params['gas_type_E10'], 3),
                        'SP98' : round(reg.params['gas_type_SP98'], 3),
                        'pvalue' : round(float(reg.t_test('gas_type_E10 = gas_type_SP98').pvalue), 2)
    }
# Out:
# 0.44765667165558365
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                consume   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     10.85
# Date:                Wed, 25 May 2022   Prob (F-statistic):           2.61e-05
# Time:                        16:44:30   Log-Likelihood:                -552.07
# No. Observations:                 388   AIC:                             1110.
# Df Residuals:                     385   BIC:                             1122.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         3.7713      0.112     33.702      0.000       3.551       3.991
# speed            -0.0176      0.004     -4.647      0.000      -0.025      -0.010
# gas_type_E10      1.9253      0.082     23.498      0.000       1.764       2.086
# gas_type_SP98     1.8460      0.071     26.104      0.000       1.707       1.985
# ==============================================================================
# Omnibus:                      251.827   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2911.405
# Skew:                           2.604   Prob(JB):                         0.00
# Kurtosis:                      15.368   Cond. No.                     3.40e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.51e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.40029285994731856
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                consume   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     28.35
# Date:                Wed, 25 May 2022   Prob (F-statistic):           1.40e-16
# Time:                        16:44:30   Log-Likelihood:                -523.90
# No. Observations:                 388   AIC:                             1056.
# Df Residuals:                     384   BIC:                             1072.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.5583      0.253     21.961      0.000       5.061       6.056
# speed            -0.1436      0.017     -8.629      0.000      -0.176      -0.111
# speed2            0.0013      0.000      7.748      0.000       0.001       0.002
# gas_type_E10      2.8201      0.138     20.374      0.000       2.548       3.092
# gas_type_SP98     2.7382      0.133     20.641      0.000       2.477       2.999
# ==============================================================================
# Omnibus:                      225.170   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2176.810
# Skew:                           2.303   Prob(JB):                         0.00
# Kurtosis:                      13.651   Cond. No.                     1.33e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.2e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.3665655638647306
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                consume   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     23.66
# Date:                Wed, 25 May 2022   Prob (F-statistic):           1.67e-17
# Time:                        16:44:30   Log-Likelihood:                -519.86
# No. Observations:                 388   AIC:                             1050.
# Df Residuals:                     383   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.4262      0.705     10.541      0.000       6.041       8.811
# speed            -0.1422      0.016     -8.621      0.000      -0.175      -0.110
# speed2            0.0013      0.000      7.771      0.000       0.001       0.002
# gas_type_E10      3.7567      0.357     10.509      0.000       3.054       4.459
# gas_type_SP98     3.6695      0.354     10.378      0.000       2.974       4.365
# temp_inside      -0.1299      0.046     -2.837      0.005      -0.220      -0.040
# ==============================================================================
# Omnibus:                      222.038   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2089.699
# Skew:                           2.271   Prob(JB):                         0.00
# Kurtosis:                      13.423   Cond. No.                     9.94e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.15e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.22222018512862968
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                consume   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     24.69
# Date:                Wed, 25 May 2022   Prob (F-statistic):           1.47e-21
# Time:                        16:44:30   Log-Likelihood:                -508.39
# No. Observations:                 388   AIC:                             1029.
# Df Residuals:                     382   BIC:                             1053.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.1883      0.687     10.469      0.000       5.838       8.538
# speed            -0.1348      0.016     -8.369      0.000      -0.166      -0.103
# speed2            0.0012      0.000      7.466      0.000       0.001       0.002
# gas_type_E10      3.6516      0.348     10.488      0.000       2.967       4.336
# gas_type_SP98     3.5368      0.345     10.256      0.000       2.859       4.215
# temp_inside      -0.1242      0.045     -2.790      0.006      -0.212      -0.037
# rain              0.6775      0.140      4.824      0.000       0.401       0.954
# ==============================================================================
# Omnibus:                      216.320   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1909.308
# Skew:                           2.219   Prob(JB):                         0.00
# Kurtosis:                      12.920   Cond. No.                     1.26e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.34e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
